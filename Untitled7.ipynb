# %%
# So we have y[0]=x, y[1]=v_{x}, y[2]=y, y[3]=v_{y}
import numpy as np
from vpython import * # must import vpython first

scene = canvas() # with this you don't need to restart kernel each time
gd = graph(x=0, y=0, width=600, height=600, 
      title='Orbit', xtitle='x', ytitle='y', 
      foreground=color.black, background=color.white, 
      xmax=2, xmin=-2, ymax=2, ymin=-2)

f1 = gcurve(color=color.cyan)	# a graphics curve  

G=1.
M=1.
tend=2.*np.pi
h=0.001
y=[1.,0.,0.,1.]
t=0
ta = np.pi
def f(t, y):
    f=np.zeros(4)
    r=np.sqrt(y[0]*y[0]+y[2]*y[2])
    f[0]=y[1]
    f[1]=-G*M/r/r/r*y[0]
    f[2]=y[3]
    f[3]=-G*M/r/r/r*y[2]
    return f
    
def eu(t, h, y, n):
    y+=h*f(t,y)
    return y
    # write Euler method
        
while(t<tend):
    if((t+h)>tend):
        h=tend-ta
    y = eu(t,h,y,4)
    t = t+h
    rate(500)
    f1.plot(pos=(y[0],y[2]))
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
# %matplotlib inline

from sympy import Eq, Symbol, solve, Derivative, function, init_printing

import matplotlib

#import math

#from math import sin, cos, tan, asin

from sympy import latex

import numpy as np

import matplotlib.pyplot as plt

import sympy

from sympy import *

import string

# %%
init_printing(use_unicode=True, wrap_line=True)  

ignored = set(string.punctuation + string.whitespace)

U = Symbol('U')
T = Symbol('T')
m = Symbol('m', integer=True)
g = Symbol('g', integer=True)
l = Symbol('l')
yes = not(ignored)

H = Symbol("H")
a = Symbol("a")
A = Symbol("A")
t = Symbol("t")
p = Symbol("p")
G = Symbol("G"),
F = Symbol("F")
M = Symbol("M")

f = Symbol("f")
k = Symbol("k")
a = Symbol("a")
L = Symbol("L")
R = Symbol("R")
v = Symbol("v")
l = Symbol("l")

r = Symbol("r")
v_z = Symbol("v_z")
v_y = Symbol("v_y")
v_x = Symbol("v_x")
y = Symbol("y")
z = Symbol("z")

x = Symbol("x")

x1 = Symbol("x1")
x2 = Symbol("x2")

y1 = Symbol("y1")
y2 = Symbol("y2")

vx1 = Symbol("vx1")
vx2 = Symbol("vx2")

vy1 = Symbol("vy1")
vy2 = Symbol("vy2")

w = Symbol('w')
R = function
Q = Symbol("a=")
o = Symbol("o")
L = function
n = Symbol("n")

J = Symbol("Equations"  "Of" ' ' "Motion""=>")
x = x(t)
v = v(t)
y = y(t)
z = z(t)
w = w(t)
o = o(t)
v_z = v_z(t)

x1 = x1(t)
x2 = x2(t)

y1 = y1(t)
y2 = y2(t)

v_y = v_y(t)
v_x = v_x(t)
th = Symbol("th")
th = th(t)

s = [x1,y1,x2,y2]
i = [vx1,vy1,vx2,vy2]

rspt = input("Respect to: ")
t = eval(rspt)
#These defaults I made are for a spring pendulum.
u = input("The Potential Energy: ")
if u == "":
    U = eval("-1/((x2-x1)**2+(y2-y1)**2)**0.5")
else:
    U = eval(u) 
H = input("The Kinetic Energy: ")                
if H == "":
    T = eval("((vx2-vx1)**2+(vy2-vy1)**2)/2.0")
else:
    T = eval(H)
    
L = T - U

#s = input("Position Variable(s), (i.e. x, r, theta,...): ")
#s = s.replace(" ","")
#i = input("Velocity Variable(s), (i.e. x_dot , y_dot ,v_x , v_y,...): ")

s = [x1,y1,x2,y2]
i = [vx1,vy1,vx2,vy2]
#i = i.replace(" ","")

#vx1 =
#vx2 = 
#vy1 = 
#vy2 =

#vx1 = function
#vx2 = function
#vy1 = function
#vy2 = function

vx1 = Function('vx1')(t)
vx2 = Function('vx2')(t) 
vy1 = Function('vy1')(t)
vy2 = Function('vy2')(t)

y = Function('y')(x)

#ax1 = Derivative(vx1(t),t).doit()
#ax2 = Derivative(vx2(t),t).doit()
#ay1 = Derivative(vy1(t),t).doit()
#ay2 = Derivative(vy2(t),t).doit()



lengthoflist1 = len(list(s))
                
lengthoflist2 = len(list(i))

adiff1 = 1.0*Derivative(i[2], t) - 1.0*Derivative(i[0], t)
adiff2 = 1.0*Derivative(i[3], t) - 1.0*Derivative(i[1], t)
    
print(adiff1)
print(adiff2) 

for r in range(0, lengthoflist1):
    
    #s[r] = s[r](t)
    #i[r] = i[r](t)

    lagrange1 = Eq(((Derivative(L, s[r]).doit())-(Derivative(Derivative(L, i[r]).doit(), t))).doit(), 0)
    print(Derivative(L, i[r]).doit(), t)

    if (r == 0 or r==2):
        adiff = adiff1
    else:
        adiff = adiff2
            
        
    acceleration1 = solve(Eq(((Derivative(L, s[r]).doit())-(Derivative(Derivative(L, i[r]).doit(), t))).doit(), 0), adiff)
    
    if(r == 0):
        acl1 = acceleration1#[0]
        
    elif(r==1):
        acl2 = acceleration1#[0]
        
    elif(r==2):
        acl3 = acceleration1#[0]
        
    elif(r==3):
        acl4 = acceleration1#[0]
    
                    #print(lagrange1)
                    #print(acceleration1)

                    #a = latex("SolveLagrangian \longrightarrow")
                    #b = latex(lagrange1)
                    #c = latex(" a") + latex("_") + latex(s[r]) + latex('=')
                    #d = latex(acceleration1)

    
    ax = plt.subplots()
    plt.axis('off')
    
    ax = plt.axes([0,0,2.2,0.5]) 

    ax.set_xticks([])

    ax.set_yticks([])
  

                                        #Lagrangian and Text
    plt.text(0.03,(0.7),'$%s$' %(latex("SolveLagrangian \longrightarrow")),size=21), plt.text(0.27,(0.7),'$%s$' %(latex(lagrange1)),size=21)
    
                                    #Solution to Respective acceleration
    plt.text(0.03,(0.22),'$%s$' %(latex(" a") + latex("_") + latex(s[r]) + latex('=')),size=24), plt.text(0.09,(0.22),'$%s$' %(latex(acceleration1)),size=24)
    plt.show()                
#Ls = list[s]
#Li = list[i]


#print(s)
#print(i)



for k  in  list(s):
    
     
        
    #if k not in (string.punctuation + string.whitespace):
            
       # k = Symbol(str(k))
         
      #  k = k(t)
            
        #print(Derivative(L, k))
            
        
        
        for n in list(i):
            
          #  if n not in (string.punctuation + string.whitespace):

              #  n = Symbol(str(n))
                
             #   n = n(t)
                
                a = Derivative(n,rspt)
               # print(a)
                
                partialderiv1 = Derivative(L, k)
                
                partialderiv2 = Derivative(L, n)
                diffpartial = Derivative(partialderiv2, t)
                calclagrangian = partialderiv1 - diffpartial
               
                eqn = Eq((calclagrangian.doit()), 0)
      
                solv = solve(eqn, Derivative(n, t) )
        
                partialderiv1 = Derivative(L, k)
                partialderiv1.doit()
                partialderiv2 = Derivative(L, n)
                diffpartial = Derivative(partialderiv2, t)
                calclagrangian = partialderiv1 - diffpartial
                calclagrangian.doit()
                eqn = Eq((calclagrangian.doit()), 0)
      
                solv = solve(eqn, Derivative(n, t))
        
                #calclagrangian.doit(), solv   
        
                #calclagrangian.doit(), solv     
                
                #print(diffpartial.doit())
                
                #print("0 =", calclagrangian.doit())
                
                
                
                partialderiv1 = Derivative(L, k)
                #partialderiv1.doit()
                partialderiv2 = Derivative(L, n)
                diffpartial = Derivative(partialderiv2, t)
                calclagrangian = partialderiv1 - diffpartial
                #calclagrangian.doit()
                eqn = Eq((calclagrangian.doit()), 0)
                #For moving plane
                #(M*v**2)/2 + m*(w**2 +(tan(z)**2)*(v+w)**2)/2
                #-(m*g*(x + y))* tan(z)
                
                #(m*(l**2)*(w**2) + x**2 + 2*l*v*w*(cos(y)))/2
                # -1/((x2-x1)**2+(y2-y1)**2)**0.5
                # (m*v**2)/2 + (m*w**2)/2
                # ((vx2-vx1)**2+(vy2-vy1)**2)/2.0
Derivative(L, k).doit(),  Derivative(L, n).doit()
                
(J)(calclagrangian.doit()), (Q), (solv)
# Out:
# Respect to: t
# The Potential Energy:
# The Kinetic Energy:
# -1.0*Derivative(vx1, t) + 1.0*Derivative(vx2, t)
# -1.0*Derivative(vy1, t) + 1.0*Derivative(vy2, t)
# 1.0*vx1 - 1.0*vx2 t
# 1.0*vy1 - 1.0*vy2 t
# -1.0*vx1 + 1.0*vx2 t
# -1.0*vy1 + 1.0*vy2 t
# ⎛                    ⎛                                       -1.5
# ⎜                    ⎜⎛                2                   2⎞
# ⎝EquationsOf Motion=>⎝⎝(-x₁(t) + x₂(t))  + (-y₁(t) + y₂(t)) ⎠    ⋅(1.0⋅y₁(t) -
#
#            ⎞        ⎞
#            ⎟        ⎟
#  1.0⋅y₂(t))⎠, a=, []⎠

# %%
# t = np.linspace(0,20)
# print(acceleration1)
# ac1 = acceleration1[0]
# print(acceleration1)

# ya = [0.75, 0., 0.33, 1/np.sqrt(2),   # [x_1, v_x_1, y_1, v_y_1
#      -0.25, 0., 0.33, -1/np.sqrt(2)]
print(-acl1) # 1
print(acl2) # 
print(-acl3) # 
print(acl4) # 
# -acl1 # 1
# acl2 # 
# -acl3 # 
# acl4 # 


#f = lambda x1 : ac1

#f(5)

# print(type(ac1))
# q1=acl1.subs([(x1,ya[0]),(x2,ya[4]),(y1,ya[2]),(y2,ya[6])])
# print(q1)
# acl1.subs(x1, x1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-56f81d6c4fe6> in <module>()
#       6 # ya = [0.75, 0., 0.33, 1/np.sqrt(2),   # [x_1, v_x_1, y_1, v_y_1
#       7 #      -0.25, 0., 0.33, -1/np.sqrt(2)]
# ----> 8 print(-acl1) # 1
#       9 print(acl2) #
#      10 print(-acl3) #
#
# TypeError: bad operand type for unary -: 'list'

# %%
-acl2.subs(x1, x1)

# %%
acl3.subs(x1, x1)

# %%
acl4.subs(x1, x1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-3d2cd9ee7f6f> in <module>()
# ----> 1 acl4.subs(x1, x1)
#
# AttributeError: 'list' object has no attribute 'subs'

# %%
ya = np.zeros(8)
fa = np.zeros(8)

# %%
# x(2)
# ac1.subs(x1, 5)
# expr.subs([(x, 2), (y, 4), (z, 0)])

# %%
# def f(t, y, acl1,acl2,acl3,acl4):
#     # GM_i = 1,    i = 1,2
#     #rx = y[0] - y[4]           # Displacement vector components
#     #ry = y[2] - y[6]           # from 2 to 1
#     #r = np.sqrt(rx**2 + ry**2) # magnitude of DV
#     f = np.zeros(8)
#     f[0] = y[1]                # dx_1/dt = v_x_1
#     f[1] = acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])  # dv_x_1/dt = F12_x = -GMr_x/r^3
#     f[2] = y[3]                # dy_1/dt = v_y_1
#     f[3] = acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])       # dv_y_1/dt = F12_y = -GMr_y/r^3
#     f[4] = y[5]                # dx_2/dt = v_x_2
#     f[5] = acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])        # dv_x_2/dt = F21_x = -F12_x
#     f[6] = y[7]                # dy/dt = v_y
#     f[7] = acl4.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])       # dv_y_2/dt = F21_y = -F12_y
#     return f

# %%
# So we have y[0]=x, y[1]=v_{x}, y[2]=y, y[3]=v_{y}
# import numpy as np
# from vpython import * # must import vpython first

# scene = canvas() # with this you don't need to restart kernel each time
# gd = graph(x=0, y=0, width=600, height=600, 
#       title='Orbit', xtitle='x', ytitle='y', 
#       foreground=color.black, background=color.white, 
#       xmax=2, xmin=-2, ymax=2, ymin=-2)

# f1 = gcurve(color=color.cyan)	# a graphics curve  

# G=1.
# M=1.
# tend=2.*np.pi
# h=0.001
# y=[1.,0.,0.,1.]
# t=0


# #f(t, ya, acl1,acl2,acl3,acl4)

# # def f(t, y):
# #     f=np.zeros(4)
# #     r=np.sqrt(y[0]*y[0]+y[2]*y[2])
# #     f[0]=y[1]
# #     f[1]=-G*M/r/r/r*y[0]
# #     f[2]=y[3]
# #     f[3]=-G*M/r/r/r*y[2]
# #     return f
    
# # def eu(t, h, y, n):
# #     y+=h*f(t,y)
# #     return y
# #     # write Euler method
        
# # while(t<tend):
# #     if((t+h)>tend):
# #         h=tend-ta
# #     y = eu(t,h,y,4)
# #     t = t+h
# #     rate(500)
# #     f1.plot(pos=(y[0],y[2]))
    
# x1a = []
# x2a = []
# y1a = []
# y2a = []

# y=[1.0,0.,0.0,0.3, -1.0,0.,0.,-0.3]
# q1 = y[0] - y[4]           
# q2 = y[2] - y[6]  
# Rb = np.sqrt(q1**2 + q2**2)  
# h = 0.01
# t= 0
# tend = np.sqrt(2.0*4.0*(np.pi**2)* (Rb**3))



# while(t<tend):
    
#     if((t+h)>tend):
#         h=tend-t
#         ya =rk4(t,h,ya,f)
# #     y = rk4(ya,t,h)
#     x1a=np.append(x1a,ya[0])
#     y1a=np.append(y1a,ya[2])
#     x2a=np.append(x2a,ya[4])
#     y2a=np.append(y2a,ya[6])
#     t = t+h
    
# plt.xlabel("x")
# plt.ylabel("y")

# plt.plot(x1a,y1a,label="Star 1")
# plt.plot(x2a,y2a,label="Star 2")

# plt.show()
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-234-5aa051920471> in <module>()
#      62     if((t+h)>tend):
#      63         h=tend-t
# ---> 64         ya =rk4(t,h,ya,f)
#      65 #     y = rk4(ya,t,h)
#      66     x1a=np.append(x1a,ya[0])
#
# <ipython-input-143-07198d1da8b8> in rk4(t, h, y, f)
#      57         containing no derivatives of its terms.
#      58     """
# ---> 59     k1 = h*f(t, y, acl1,acl2,acl3,acl4)
#      60     k2 = h*f(t + 0.5*h, y + 0.5*k1, acl1,acl2,acl3,acl4)
#      61     k3 = h*f(t + 0.5*h, y + 0.5*k2, acl1,acl2,acl3,acl4)
#
# TypeError: f() takes 2 positional arguments but 6 were given

# %%
# def rk4a(y,t,h): # h being the interval step
#     k1=np.zeros(8) # This is borrowed from lecture.
#     k2=np.zeros(8)
#     k3=np.zeros(8)
#     k4=np.zeros(8)

#     k1 = h*f(t, y, acl1,acl2,acl3,acl4)
#     k2 = h*f(t + (1.0/2.0)*h, y + (1.0/2.0)*k1, acl1,acl2,acl3,acl4)
#     k3 = h*f(t + (1.0/2.0)*h, y + (1.0/2.0)*k2, acl1,acl2,acl3,acl4)
#     k4 = h*f(t + h, y + k3, acl1,acl2,acl3,acl4)
    
#     y = y +  (k1 + 2 * k2 + 2 * k3 + k4)/6.0
    
#     return y

# %%
# x1a = []
# x2a = []
# y1a = []
# y2a = []

# ya=[1.0,0.,0.0,0.3, -1.0,0.,0.,-0.3]
# q1 = ya[0] - ya[4]           
# q2 = ya[2] - ya[6]  
# Rb = np.sqrt(q1**2 + q2**2)  
# h = 0.01
# t= 0
# tend = np.sqrt(2.0*4.0*(np.pi**2)* (Rb**3))



# while(t<tend):
    
#     if((t+h)>tend):
#         h=tend-t
#     ya = rk4a(ya,t,h)
#     x1a=np.append(x1a,ya[0])
#     y1a=np.append(y1a,ya[2])
#     x2a=np.append(x2a,ya[4])
#     y2a=np.append(y2a,ya[6])
#     t = t+h
    
# plt.xlabel("x")
# plt.ylabel("y")

# plt.plot(x1a,y1a,label="Star 1")
# plt.plot(x2a,y2a,label="Star 2")

# plt.show()

# %%
# #rk4a(ya,t,h)
# print(type(ya))
# ya

# %%
def g(acl1,acl2,acl3,acl4,y):
    za = np.zeros(4)
    za[0]= -acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
    za[1]= -acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
    za[2]= acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
    za[3]= acl4.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
    return [za[0],za[1],za[2],za[3]]

# %%
print(g(acl1,acl2,acl3,acl4,ya))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-233c91fdcc26> in <module>()
# ----> 1 print(g(acl1,acl2,acl3,acl4,ya))
#
# NameError: name 'ya' is not defined

# %%
def f3(t,y):       
#     q1 = y[0] - y[4]           
#     q2 = y[2] - y[6]      
    
    #R = np.sqrt(q1**2 + q2**2)  
    f = np.zeros(8) # This is borrowed from lecture.
    z3 =np.zeros(4)
    z3 = g(acl1,acl2,acl3,acl4,y)
    f[0] = y[1]                
    f[1] = z3[0]   
    #print(f[1])
    f[2] = y[3]               
    f[3] = z3[1]        
    f[4] = y[5]                
    f[5] = z3[2]         
    f[6] = y[7]                
    f[7] = z3[3]    
    return f

# %%
f3(0,ya)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5269734a6993> in <module>()
# ----> 1 f3(0,ya)
#
# NameError: name 'ya' is not defined

# %%
def rk4b(y,t,h): # h being the interval step
    k1=np.zeros(8) # This is borrowed from lecture.
    k2=np.zeros(8)
    k3=np.zeros(8)
    k4=np.zeros(8)

    k1 = h*f3(t, y)
    k2 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k1)
    k3 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k2)
    k4 = h*f3(t + h, y + k3)
    
    y = y +  (k1 + 2 * k2 + 2 * k3 + k4)/6.0
    
    return y

# %%
rk4b(ya,0,0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b485ff1ae871> in <module>()
# ----> 1 rk4b(ya,0,0.01)
#
# NameError: name 'ya' is not defined

# %%
x1a = []
x2a = []
y1a = []
y2a = []

ya=[1.0,0.,0.0,0.3, -1.0,0.,0.,-0.3]
q1 = ya[0] - ya[4]           
q2 = ya[2] - ya[6]  
Rb = np.sqrt(q1**2 + q2**2)  
h = 0.01
t = 0
#tend = np.sqrt(2.0*4.0*(np.pi**2)* (Rb**3))
tend = 2*np.pi


while(t<tend):
    
    if((t+h)>tend):
        h=tend-t
    ya = rk4b(ya,t,h)
    x1a=np.append(x1a,ya[0])
    y1a=np.append(y1a,ya[2])
    x2a=np.append(x2a,ya[4])
    y2a=np.append(y2a,ya[6])
    t = t+h
    
plt.xlabel("x")
plt.ylabel("y")

plt.plot(x1a,y1a,label="Star 1")
plt.plot(x2a,y2a,label="Star 2")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-53ab81336ca6> in <module>()
#      18     if((t+h)>tend):
#      19         h=tend-t
# ---> 20     ya = rk4b(ya,t,h)
#      21     x1a=np.append(x1a,ya[0])
#      22     y1a=np.append(y1a,ya[2])
#
# <ipython-input-15-d89cd7317429> in rk4b(y, t, h)
#       5     k4=np.zeros(8)
#       6
# ----> 7     k1 = h*f3(t, y)
#       8     k2 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k1)
#       9     k3 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k2)
#
# <ipython-input-13-6d9a0492b44e> in f3(t, y)
#       6     f = np.zeros(8) # This is borrowed from lecture.
#       7     z3 =np.zeros(4)
# ----> 8     z3 = g(acl1,acl2,acl3,acl4,y)
#       9     f[0] = y[1]
#      10     f[1] = z3[0]
#
# <ipython-input-11-8021117ab2d4> in g(acl1, acl2, acl3, acl4, y)
#       1 def g(acl1,acl2,acl3,acl4,y):
#       2     za = np.zeros(4)
# ----> 3     za[0]= -acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       4     za[1]= -acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       5     za[2]= acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#
# AttributeError: 'list' object has no attribute 'subs'

# %%
rk4b(ya,0,0.01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b485ff1ae871> in <module>()
# ----> 1 rk4b(ya,0,0.01)
#
# <ipython-input-15-d89cd7317429> in rk4b(y, t, h)
#       5     k4=np.zeros(8)
#       6
# ----> 7     k1 = h*f3(t, y)
#       8     k2 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k1)
#       9     k3 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k2)
#
# <ipython-input-13-6d9a0492b44e> in f3(t, y)
#       6     f = np.zeros(8) # This is borrowed from lecture.
#       7     z3 =np.zeros(4)
# ----> 8     z3 = g(acl1,acl2,acl3,acl4,y)
#       9     f[0] = y[1]
#      10     f[1] = z3[0]
#
# <ipython-input-11-8021117ab2d4> in g(acl1, acl2, acl3, acl4, y)
#       1 def g(acl1,acl2,acl3,acl4,y):
#       2     za = np.zeros(4)
# ----> 3     za[0]= -acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       4     za[1]= -acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       5     za[2]= acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#
# AttributeError: 'list' object has no attribute 'subs'

# %%
f3(0,ya)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-5269734a6993> in <module>()
# ----> 1 f3(0,ya)
#
# <ipython-input-13-6d9a0492b44e> in f3(t, y)
#       6     f = np.zeros(8) # This is borrowed from lecture.
#       7     z3 =np.zeros(4)
# ----> 8     z3 = g(acl1,acl2,acl3,acl4,y)
#       9     f[0] = y[1]
#      10     f[1] = z3[0]
#
# <ipython-input-11-8021117ab2d4> in g(acl1, acl2, acl3, acl4, y)
#       1 def g(acl1,acl2,acl3,acl4,y):
#       2     za = np.zeros(4)
# ----> 3     za[0]= -acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       4     za[1]= -acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       5     za[2]= acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#
# AttributeError: 'list' object has no attribute 'subs'

# %%
import numpy as np
from vpython import * # must import vpython first

scene = canvas() # with this you don't need to restart kernel each time
gd = graph(x=0, y=0, width=600, height=600, 
      title='Orbit', xtitle='x', ytitle='y', 
      foreground=color.black, background=color.white, 
      xmax=2, xmin=-2, ymax=2, ymin=-2)

f1 = gcurve(color=color.cyan)	# a graphics curve  
f2 = gcurve(color=color.green)	# a graphics curve  

G=1.
M=1.
tend=2.*np.pi
h=0.001
ya=[1.,0.,0.,1.]
t = 0


    
x1a = []
x2a = []
y1a = []
y2a = []


tend = 2*np.pi

x1a = []
x2a = []
y1a = []
y2a = []

ya=[1.0,0.,0.0,0.3, -1.0,0.,0.,-0.3]
q1 = ya[0] - ya[4]           
q2 = ya[2] - ya[6]  
Rb = np.sqrt(q1**2 + q2**2)  
h = 0.01
t = 0
#tend = np.sqrt(2.0*4.0*(np.pi**2)* (Rb**3))
tend = 2*np.pi


while(t<tend):
    
    if((t+h)>tend):
        h=tend-t
    ya = rk4b(ya,t,h)
    x1a=np.append(x1a,ya[0])
    y1a=np.append(y1a,ya[2])
    x2a=np.append(x2a,ya[4])
    y2a=np.append(y2a,ya[6])
    t = t+h
    rate(900)
    f1.plot(pos=(ya[0],ya[2]))
    f2.plot(pos=(ya[4],ya[6]))
plt.xlabel("x")
plt.ylabel("y")

plt.plot(x1a,y1a,label="Star 1")
plt.plot(x2a,y2a,label="Star 2")

plt.show()
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8130275131e4> in <module>()
#      47     if((t+h)>tend):
#      48         h=tend-t
# ---> 49     ya = rk4b(ya,t,h)
#      50     x1a=np.append(x1a,ya[0])
#      51     y1a=np.append(y1a,ya[2])
#
# <ipython-input-15-d89cd7317429> in rk4b(y, t, h)
#       5     k4=np.zeros(8)
#       6
# ----> 7     k1 = h*f3(t, y)
#       8     k2 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k1)
#       9     k3 = h*f3(t + (1.0/2.0)*h, y + (1.0/2.0)*k2)
#
# <ipython-input-13-6d9a0492b44e> in f3(t, y)
#       6     f = np.zeros(8) # This is borrowed from lecture.
#       7     z3 =np.zeros(4)
# ----> 8     z3 = g(acl1,acl2,acl3,acl4,y)
#       9     f[0] = y[1]
#      10     f[1] = z3[0]
#
# <ipython-input-11-8021117ab2d4> in g(acl1, acl2, acl3, acl4, y)
#       1 def g(acl1,acl2,acl3,acl4,y):
#       2     za = np.zeros(4)
# ----> 3     za[0]= -acl1.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       4     za[1]= -acl2.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#       5     za[2]= acl3.subs([(x1,y[0]),(x2,y[4]),(y1,y[2]),(y2,y[6])])
#
# AttributeError: 'list' object has no attribute 'subs'
